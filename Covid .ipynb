# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# to avoid truncated error add r before pathname of a file
data=pd.read_csv(r'/Users/sumatim/Documents/My Tableau Repository/Workbooks/covid19-ita-regions.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'region', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made', 'note_it', 'note_en'],
#       dtype='object')

# %%
data.drop('region', axis=1, inplace=True)

# %%
data.tail()
# Out:
#       Unnamed: 0                 date state  hospitalized_with_symptoms  \
# 1465        1465  2020-05-03T17:00:00   ITA                         513
# 1466        1466  2020-05-03T17:00:00   ITA                         136
# 1467        1467  2020-05-03T17:00:00   ITA                          58
# 1468        1468  2020-05-03T17:00:00   ITA                          74
# 1469        1469  2020-05-03T17:00:00   ITA                         955
#
#       intensive_care  total_hospitalized  home_quarantine  \
# 1465             112                 625             4703
# 1466              17                 153             1094
# 1467              13                  71              112
# 1468               2                  76               33
# 1469             103                1058             6241
#
#       total_confirmed_cases  variation_total_confirmed  new_confirmed_cases  \
# 1465                   5328                        -37                   38
# ...

# %%
# to represent maximum rows
pd.set_option('display.max_rows', None)
# describes all the basic mathematical functions
data.describe()
# Out:
#         Unnamed: 0  hospitalized_with_symptoms  intensive_care  \
# count  1470.000000                 1470.000000     1470.000000
# mean    734.500000                  827.292517      105.958503
# std     424.496761                 1907.428144      206.199386
# min       0.000000                    0.000000        0.000000
# 25%     367.250000                   31.000000        6.000000
# 50%     734.500000                  164.000000       31.000000
# 75%    1101.750000                  671.000000      112.000000
# max    1469.000000                12077.000000     1381.000000
#
#        total_hospitalized  home_quarantine  total_confirmed_cases  \
# count         1470.000000      1470.000000            1470.000000
# mean           933.251020      1970.851701            2904.102721
# std           2108.557619      3911.031974            5772.433128
# min              0.000000         0.000000               0.000000
# ...

# %%
# to count the number of null values
data.isnull().sum()
# Out:
# Unnamed: 0                       0
# date                             0
# state                            0
# hospitalized_with_symptoms       0
# intensive_care                   0
# total_hospitalized               0
# home_quarantine                  0
# total_confirmed_cases            0
# variation_total_confirmed        0
# new_confirmed_cases              0
# recovered                        0
# deaths                           0
# total_cases                      0
# swabs_made                       0
# note_it                       1448
# note_en                       1448
# dtype: int64

# %% [markdown]
# # Relating the variables with Scatterplot

# %%
sns.relplot(x="total_confirmed_cases", y="hospitalized_with_symptoms",hue="recovered", data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="home_quarantine", y="total_cases", kind='line', data=data)

# %%
# categorical plot to categorize in different categories
sns.catplot(x="recovered", y="total_cases", data=data)
